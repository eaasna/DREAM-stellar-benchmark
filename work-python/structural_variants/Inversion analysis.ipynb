# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# ## Structural variant gold set

# %% [markdown]
# ## Inversions from valik

# %%
XXSMALL_SIZE = 10
XSMALL_SIZE = 10
SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 14

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=XSMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=XSMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=XSMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=MEDIUM_SIZE)  # fontsize of the figure title

c_darkblue = "#4c6c9c"
c_darkgreen = "#5e8f7b"
c_purple = "#947db0"
c_positive = "#FF726E"
c_negative = "#6E76FF"

# %%
def read_stellar_output(filename):
    df = pd.read_csv(filename, sep = "\t", header = None)
    df.drop([1, 2, 7], axis = 1, inplace = True) 
    df.columns = ["dname", "dbegin", "dend", "percid", "strand", "attr"]
    df["len"] = np.abs(df["dend"] - df["dbegin"])
    df[['qname','seq2Range', 'evalue', 'cigar', 'mutations']] = df['attr'].str.split(';',expand=True)
    df[["qbegin", "qend"]] = df["seq2Range"].str.removeprefix("seq2Range=").str.split(',',expand=True)
    df.drop(["cigar", "mutations", "evalue", "attr", "seq2Range"], axis = 1, inplace = True)
    for col in ["dbegin", "dend", "qbegin", "qend"]:
        df[col] = pd.to_numeric(df[col])
    return df

# %% [markdown]
# Pick reads that align to both strands

# %%
def get_split_variants(variants, min_seq_count):
    split_read_variants = pd.DataFrame().reindex(columns=variants.columns) 
    split_reads = []
    for qname in np.unique(variants["qname"]): 
        query_matches = variants[variants["qname"] == qname]
        for dname in np.unique(query_matches["dname"]):
            chr_query_matches = query_matches[query_matches["dname"] == dname]
            if (len(chr_query_matches) >= min_seq_count):
                if (len(np.unique(chr_query_matches["strand"])) == 2):
                    split_reads.append(qname)
                    split_read_variants = pd.concat([split_read_variants, chr_query_matches])
                    break

    variants = split_read_variants
    return variants

# %% [markdown]
# Switch database begin and end for variants on the minus strand

# %%
def switch_reverse_coord(variants):
    plus = variants[variants["strand"] == "+"].copy()
    minus = variants[variants["strand"] == "-"].copy()
    minus["tmp"] = minus["dbegin"].copy()
    minus["dbegin"] = minus["dend"].copy()
    minus["dend"] = minus["tmp"]
    minus.drop(["tmp"], inplace = True, axis = 1)
    variants = pd.concat([plus, minus])
    for col in ["dbegin", "dend", "qbegin", "qend"]:
        variants[col] = pd.to_numeric(variants[col])
    return variants

# %% [markdown]
# ### Find best fitting line

# %%
def line_params(best_matches):
    i = 0

    x1 = best_matches["dbegin"].iloc[i]
    x2 = best_matches["dend"].iloc[i]
    y1 = best_matches["qbegin"].iloc[i]
    y2 = best_matches["qend"].iloc[i]

    a = (y2 - y1) / (x2 - x1)
    b = y1 - a * x1
    return [a, b]

def get_line(a, b):
    y_line = [0, 14000]
    x_line = []
    for y in y_line:
        x_line.append((y - b) / a)
    return x_line

# %%
def fit_line_coord(variants):
    variants = variants.assign(a = lambda x: ((x["qend"] - x["qbegin"]) / (x["dend"] - x["dbegin"])))
    variants = variants.assign(b = lambda x: (x["qbegin"] - x["a"] * x["dbegin"]))

    return variants

# %% [markdown]
# Find alignments that are on the same line

# %%
def get_aligned(df, max_offset):
    min_seq_range = 100
    read_len = 20000
    read_sets = []
    split_reads = []
    #chr_dict = {k:[] for k in np.unique(df["dname"])}

    for index, row in df.iterrows():
        query_matches = df[(df["qname"] == row["qname"]) & 
                        (df["dname"] == row["dname"])]
        if (row["dname"] not in ["chrY", "chr16_KI270728v1_random"]):
            if (len(np.unique(query_matches["strand"])) == 2):
                region_matches = query_matches[(query_matches["dbegin"] > row["dbegin"] - row["qbegin"]) & 
                                            (query_matches["dend"] < row["dend"] + read_len - row["qend"])]
                b = row["b"]
                b_matches = region_matches[(region_matches["b"] > b - max_offset) & (region_matches["b"] < b + max_offset)]
                if (np.max(b_matches["dbegin"]) - np.min(b_matches["dbegin"]) > min_seq_range): 
                    if (np.max(b_matches["qbegin"]) - np.min(b_matches["qbegin"]) > min_seq_range): 
                        if len(b_matches) > 2:
                            #chr_dict[row["dname"]].append(row["qname"])
                            split_reads.append(row["qname"])
                            read_sets.append(b_matches)
                            print(str(len(split_reads)) + "\t" + str(row["qname"]))
    return [read_sets, split_reads]

def get_aligned_single_strand(df, max_offset):
    min_seq_range = 200
    read_len = 20000
    read_sets = []
    split_reads = []
    #chr_dict = {k:[] for k in np.unique(df["dname"])}

    for index, row in df.iterrows():
        query_matches = df[(df["qname"] == row["qname"]) & 
                           (df["dname"] == row["dname"])]
        if (row["dname"] not in ["chrY", "chr16_KI270728v1_random"]):
            region_matches = query_matches[(query_matches["dbegin"] > (row["dbegin"] - row["qbegin"] * 2)) & 
                                            (query_matches["dend"] < row["dend"] + read_len - row["qend"])]
            
            b = row["b"]
            b_matches = region_matches[(region_matches["b"] > b - max_offset) & (region_matches["b"] < b + max_offset)]
            if (np.max(b_matches["dbegin"]) - np.min(b_matches["dbegin"]) > min_seq_range): 
                if (np.max(b_matches["qbegin"]) - np.min(b_matches["qbegin"]) > min_seq_range): 
                    if len(b_matches) > 1:
                        #chr_dict[row["dname"]].append(row["qname"])
                        split_reads.append(row["qname"])
                        read_sets.append(b_matches)
                        print(str(len(split_reads)) + "\t" + str(row["qname"]))
    return [read_sets, split_reads]

# %% [markdown]
# ### Plot inversion

# %%
def get_other_strand(variants, best_matches):
    other_strand = "-"
    if (best_matches["strand"].iloc[0] == "-"):
        other_strand = "+"

    other_strand_matches = variants[(variants["qname"] == best_matches["qname"].iloc[0]) & 
                                    (variants["dname"] == best_matches["dname"].iloc[0]) & 
                                    (variants["strand"] == other_strand)]

    # not fur inverted duplications
    other_strand_matches = other_strand_matches[~other_strand_matches["qbegin"].isin(best_matches["qbegin"])] 
    other_strand_matches = other_strand_matches[~other_strand_matches["qend"].isin(best_matches["qend"])]
    return other_strand_matches

def plot_inversion(matches):
    for index, row in matches.iterrows():
        if row["strand"] == "+":
            plt.plot(np.array(row[["dbegin", "dend"]]), np.array(row[["qbegin", "qend"]]), 'b-', label = row["b"])
        else:
            plt.plot(np.array(row[["dbegin", "dend"]]), np.array(row[["qbegin", "qend"]]), 'r-', label = row["b"])

    y_range = np.max(matches["qend"]) - np.min(matches["qbegin"])
    x_range = np.max(matches["dend"]) - np.min(matches["dbegin"])

    if (y_range > x_range):
        plt.ylim(np.min(matches["qbegin"]) - round(y_range * 0.1), np.max(matches["qend"]) + round(y_range * 0.1))
        x_mean = round((np.max(matches["dbegin"]) + np.min(matches["dend"])) / 2)
        plt.xlim(x_mean - round(y_range * 1.1) / 2, x_mean + round(y_range * 1.1) / 2)
    else:
        plt.xlim(np.min(matches["dbegin"]) - round(x_range * 0.1), np.max(matches["dend"]) + round(x_range * 0.1))
        y_mean = round((np.max(matches["qbegin"]) + np.min(matches["qend"])) / 2)
        plt.ylim(y_mean - round(x_range * 1.1) / 2, y_mean + round(x_range * 1.1) / 2)
    
    
    plt.xlabel("GRCh38")
    plt.ylabel(matches["qname"].iloc[0])
    plt.title(matches["dname"].iloc[0])
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Breakpoint

# %%
def get_best_aligned(df, max_offset, min_seq_count, min_seq_range, single_strand):
    read_len = 10000
    read_sets = []
    split_reads = []
    #chr_dict = {k:[] for k in np.unique(df["dname"])}
    df = df[~df["dname"].isin(["chrY", "chr16_KI270728v1_random"])]    
    for qname in np.unique(df.qname):
        for dname in np.unique(df.dname):
            best_query_set = []
            best_score = 0
            query_matches = df[(df["qname"] == qname) & (df["dname"] == dname)]
            for index, row in query_matches.iterrows():
                region_matches = query_matches[(query_matches["dbegin"] > row["dbegin"] - row["qbegin"]) & 
                                                (query_matches["dend"] < row["dend"] + read_len - row["qend"])].copy()

                if (single_strand or len(np.unique(region_matches["strand"])) == 2):
                    a = row["a"]
                    b = row["b"]

                    region_matches = region_matches[region_matches.strand == row.strand]
                    #print(str(len(region_matches)) + " matches in region")
                        
                    x = (row["dbegin"] + row["dend"]) / 2
                    # fit line of current match
                    region_matches["horizontal_error"] = abs( region_matches["qbegin"] - (a * region_matches["dbegin"] + b) )
                    #print(region_matches)
        
                    # exclude outliers
                    b_matches = region_matches[region_matches["horizontal_error"] < max_offset]
                    #print(str(len(b_matches)) + " matches in alignment")
                    #print("DB range" + str(np.max(b_matches["dbegin"]) - np.min(b_matches["dbegin"])))
                    #print("Query range" + str(np.max(b_matches["qbegin"]) - np.min(b_matches["qbegin"])))
                    if (min_seq_count == 1 or np.max(b_matches["dbegin"]) - np.min(b_matches["dbegin"]) > min_seq_range): 
                        if (min_seq_count == 1 or np.max(b_matches["qbegin"]) - np.min(b_matches["qbegin"]) > min_seq_range): 
                            if len(b_matches) >= min_seq_count:
                                set_score = np.max(b_matches["qbegin"]) - np.min(b_matches["qbegin"])
                                split_reads.append(qname)
                                read_sets.append(b_matches)
                                print(str(len(split_reads)) + "\t" + str(row["qname"]) + "\t" + str(row["dname"]))                                    
    
    return [read_sets, split_reads]

def get_single_aligned(df, max_offset, min_seq_count, min_seq_range, single_strand):
    read_len = 20000
    read_sets = []
    split_reads = []
    #chr_dict = {k:[] for k in np.unique(df["dname"])}
    df = df[~df["dname"].isin(["chrY", "chr16_KI270728v1_random"])]    
    for qname in np.unique(df.qname):
        best_query_set = []
        best_score = 0    
        for dname in np.unique(df.dname):
            query_matches = df[(df["qname"] == qname) & (df["dname"] == dname)]
            for index, row in query_matches.iterrows():
                region_matches = query_matches[(query_matches["dbegin"] > row["dbegin"] - row["qbegin"]) & 
                                                (query_matches["dend"] < row["dend"] + read_len - row["qend"])].copy()
                if (single_strand or len(np.unique(region_matches["strand"])) == 2):
                    a = row["a"]
                    b = row["b"]

                    region_matches = region_matches[region_matches.strand == row.strand]
                    #print(str(len(region_matches)) + " matches in region")
                        
                    x = (row["dbegin"] + row["dend"]) / 2
                    # fit line of current match
                    region_matches["horizontal_error"] = abs( region_matches["qbegin"] - (a * region_matches["dbegin"] + b) )
                    #print(region_matches)
        
                    # exclude outliers
                    b_matches = region_matches[region_matches["horizontal_error"] < max_offset]
                    #print(str(len(b_matches)) + " matches in alignment")
                    #print("DB range" + str(np.max(b_matches["dbegin"]) - np.min(b_matches["dbegin"])))
                    #print("Query range" + str(np.max(b_matches["qbegin"]) - np.min(b_matches["qbegin"])))
                    if (min_seq_count == 1 or np.max(b_matches["dbegin"]) - np.min(b_matches["dbegin"]) > min_seq_range): 
                        if (min_seq_count == 1 or np.max(b_matches["qbegin"]) - np.min(b_matches["qbegin"]) > min_seq_range): 
                            if len(b_matches) >= min_seq_count:
                                set_score = np.max(b_matches["qbegin"]) - np.min(b_matches["qbegin"])
                                if (set_score > best_score):
                                    best_query_set = b_matches
            
        if (len(best_query_set) != 0):
            split_reads.append(qname)
            read_sets.append(best_query_set)
            print(str(len(split_reads)) + "\t" + str(row["qname"]) + "\t" + str(row["dname"]))                                    
    
    return [read_sets, split_reads]

# %%
def plot_all_inversions(read_sets, variants, max_offset, min_seq_count, min_seq_range, read_len):
    i = 0
    other_set_sets = []
    for best_matches in read_sets:
        if (best_matches["dname"].iloc[0] != "false"):
            other_strand = "-"
            if (best_matches["strand"].iloc[0] == "-"):
                other_strand = "+"

            other_strand_matches = df[(df["qname"] == best_matches["qname"].iloc[0]) & 
                                      (df["dname"] == best_matches["dname"].iloc[0]) & 
                                      (df["strand"] == other_strand)].copy()

            other_strand_matches["sum"] = (other_strand_matches["dbegin"] + other_strand_matches["dend"] + 
                                           other_strand_matches["qbegin"] + other_strand_matches["qend"]) // 10
            other_strand_matches.sort_values(["sum", "len"], inplace = True)
            other_strand_matches.drop_duplicates(subset = ["sum"], inplace = True)
            
            other_strand_matches = other_strand_matches[(other_strand_matches["dbegin"] > (np.min(best_matches["dbegin"]) - round(read_len/2))) & 
                                                (other_strand_matches["dbegin"] < (np.max(best_matches["dbegin"]) + round(read_len/2)))]
            print("Match count on other strand\t" + str(len(other_strand_matches)))
            if (len(other_strand_matches) > 0):
                other_read_sets, other_split_reads = get_best_aligned(other_strand_matches, 
                                                                        max_offset = 100,
                                                                        min_seq_count = 4, 
                                                                        min_seq_range = 50, 
                                                                        single_strand = True)
                other_set_sets.append(other_read_sets)
                
                print("Other strand match set count\t" + str(len(other_set_sets)))
                for other_best in other_read_sets:
                    plot_inversion(pd.concat([best_matches, other_best]))
            else:
                other_set_sets.append([])
            i += 1
    return other_set_sets

# %% [markdown]
# ### HG00731

# %% [markdown]
# #### chr2 inversion

# %%
df = read_stellar_output("HG00731.inversion.chr2.gff")
len(df)
# Out:
# 376

# %%
df = switch_reverse_coord(df)
df = fit_line_coord(df)
df.head()
# Out:
#   dname      dbegin        dend   percid strand    len  \
# 0  chr2  89832518.0  89832724.0  85.2380      +  206.0
# 1  chr2  89833094.0  89833300.0  85.1851      +  206.0
# 3  chr2  89831054.0  89831260.0  85.3773      +  206.0
# 4  chr2  89828190.0  89828397.0  85.4460      +  207.0
# 7  chr2  89832150.0  89832357.0  85.2534      +  207.0
#
#                                 qname  qbegin    qend         a             b
# 0  m54329U_190531_175004/98699610/ccs  2668.0  2869.0  0.975728 -8.764945e+07
# 1  m54329U_190531_175004/98699610/ccs  2661.0  2868.0  1.004854 -9.026652e+07
# 3  m54329U_190531_175004/98699610/ccs  3260.0  3464.0  0.990291 -8.895565e+07
# 4  m54329U_190531_175004/98699610/ccs  3260.0  3463.0  0.980676 -8.808912e+07
# 7  m54329U_190531_175004/98699610/ccs  5200.0  5411.0  1.019324 -9.156284e+07

# %%
for qname in np.unique(df["qname"]):
    print(qname)
    plot_inversion(df[df["qname"] == qname])
# Out:
# m54329U_190528_231241/23988940/ccs
# m54329U_190531_175004/98699610/ccs

# %%
df = df[df["qname"] == "m54329U_190528_231241/23988940/ccs"]
#df = df[df["dbegin"] > 8.9828 * 1e7]
read_sets, split_reads = get_single_aligned(df, max_offset = 2000, min_seq_count = 2, min_seq_range = 6500, single_strand = False)
# Out:
# 1	m54329U_190528_231241/23988940/ccs	chr2

# %%
other_set_sets = plot_all_inversions(read_sets, df, max_offset = 100, min_seq_count = 4, min_seq_range = 50, read_len = 10000)
# Out:
# Match count on other strand	59
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 2	m54329U_190528_231241/23988940/ccs	chr2
# 3	m54329U_190528_231241/23988940/ccs	chr2
# 4	m54329U_190528_231241/23988940/ccs	chr2
# 5	m54329U_190528_231241/23988940/ccs	chr2
# 6	m54329U_190528_231241/23988940/ccs	chr2
# 7	m54329U_190528_231241/23988940/ccs	chr2
# 8	m54329U_190528_231241/23988940/ccs	chr2
# Other strand match set count	1

# %%
def plot_breakpoint(df, above_set, below_set, inv_set):
    plotted_matches = pd.concat([df, inv_set])
    
    fig, ax = plt.subplots(1, 2, sharey = False, layout = "tight")
    ax[0].set_box_aspect(9/12)
    ax[1].set_box_aspect(9/12)
    fig.set_figwidth(9)
    fig.set_figheight(3.9)

    absolute_range = [round(np.min(below_set["dbegin"])) - 500, round(np.min(below_set["dbegin"])) - 500 + 12000]
    # relative position on database seq
    rel_pos_corr = np.min(below_set["dbegin"]) - 500
    print(rel_pos_corr)
    df["dbegin"] = df["dbegin"] - rel_pos_corr
    df["dend"] = df["dend"] - rel_pos_corr

    above_set["dbegin"] = above_set["dbegin"] - rel_pos_corr
    above_set["dend"] = above_set["dend"] - rel_pos_corr

    below_set["dbegin"] = below_set["dbegin"] - rel_pos_corr
    below_set["dend"] = below_set["dend"] - rel_pos_corr

    inv_set["dbegin"] = inv_set["dbegin"] - rel_pos_corr
    inv_set["dend"] = inv_set["dend"] - rel_pos_corr

    matches = pd.concat([above_set, below_set, inv_set])
    y_range = np.max(matches["qend"]) - np.min(matches["qbegin"])
    x_range = np.max(matches["dend"]) - np.min(matches["dbegin"])
    for i in range(2):
        ax[i].set_ylim(0, 9000)
        ax[i].set_xlim(0, 12000)
        ax[i].set_yticks([0, 2000, 4000, 6000, 8000])
        ax[0].set_ylabel(matches["qname"].iloc[0])
    
    if (False):
        if (y_range > x_range):
            min_y_lim = np.min(matches["qbegin"]) - round(y_range * 0.1)
            max_corr = 0
            if (min_y_lim < 0):
                max_corr = -min_y_lim
                min_y_lim = 0
                
            ax[i].set_ylim(min_y_lim, np.max(matches["qend"]) + round(y_range * 0.1) + max_corr)
            x_mean = round((np.max(matches["dbegin"]) + np.min(matches["dend"])) / 2)
            ax[i].set_xlim(x_mean - round(y_range * 1.1) / 2, x_mean + round(y_range * 1.1) / 2)
        else:
            ax[i].set_xlim(round(np.min(matches["dbegin"]) - x_range * 0.1), np.max(matches["dend"]) + round(x_range * 0.1))
            y_mean = round((np.max(matches["qbegin"]) + np.min(matches["qend"])) / 2)
            min_y_lim = round(y_mean - round(x_range * 1.1) / 2)
            max_corr = 0
            if (min_y_lim < 0):
                max_corr = -min_y_lim
                min_y_lim = 0
            
            ax[i].set_ylim(min_y_lim, y_mean + round(x_range * 1.1) / 2 + max_corr)
        print(ax[i].get_xticks())
        ax[i].set_yticks(ax[i].get_xticks())
    
    # left
    matches = pd.concat([df, inv_set])
    for index, row in matches.iterrows():
        if (row["strand"] == "+"):
            ax[0].plot(np.array(row[["dbegin", "dend"]]), np.array(row[["qbegin", "qend"]]), '-', color = c_positive, label = row["b"], linewidth = 1)
        else:
            ax[0].plot(np.array(row[["dbegin", "dend"]]), np.array(row[["qbegin", "qend"]]), '-', color = c_negative, label = row["b"], linewidth = 1)

    
    # right
    for index, row in df[df["qname"] == above_set["qname"].iloc[0]].iterrows():
        if row["strand"] == "+":
            ax[1].plot(np.array(row[["dbegin", "dend"]]), np.array(row[["qbegin", "qend"]]), '-', color = c_positive, linewidth = 0.2)
        else:
            ax[1].plot(np.array(row[["dbegin", "dend"]]), np.array(row[["qbegin", "qend"]]), '-', color = c_negative, linewidth = 0.2)
    
    matches = pd.concat([above_set, below_set, inv_set])
    for index, row in pd.concat([above_set, below_set]).iterrows():
        ax[1].plot(np.array(row[["dbegin", "dend"]]), np.array(row[["qbegin", "qend"]]), '-', color = c_positive)

    for index, row in inv_set.iterrows():
        ax[1].plot(np.array(row[["dbegin", "dend"]]), np.array(row[["qbegin", "qend"]]), '-', color = c_negative)

    #print("inv_set\n")
    #print(inv_set)

    ax[1].plot([np.min(below_set["dbegin"]), np.max(below_set["dend"])], [np.min(below_set["qbegin"]), np.max(below_set["qend"])], '-', color = c_positive, linewidth=0.3)
    ax[1].plot([np.min(above_set["dbegin"]), np.max(above_set["dend"])], [np.min(above_set["qbegin"]), np.max(above_set["qend"])], '-', color = c_positive, linewidth=0.3)
    
    
    min_match = inv_set[inv_set["dbegin"] == np.min(inv_set["dbegin"])].iloc[0]
    max_match = inv_set[inv_set["dend"] == np.max(inv_set["dend"])].iloc[0]
    ax[1].plot([max_match["dend"], min_match["dbegin"]], [max_match["qend"], min_match["qbegin"]], '-', color = c_negative, linewidth=0.3)
    ax[0].set_title("Local alignments")
    ax[1].set_title("Inverted translocation")
    range_start = int(round(absolute_range[0]/1000, 0))
    range_end = int(round(absolute_range[1]/1000, 0))
    fig.suptitle("chr2: " + str(f"{range_start:,d}") + "-" + str(f"{range_end:,d}") + " kb", size = BIGGER_SIZE)
    fig.tight_layout()
    #fig.savefig(matches["dname"].iloc[0] + '.png', dpi = 500)
    fig.savefig(matches["dname"].iloc[0] + '.svg')
    return plotted_matches

# %%
int(round(12011/1000, 0))
# Out:
# 12

# %%
for reads in read_sets:
    for inv_sets in other_set_sets:
        for inv_set in inv_sets:
            qname = inv_set.qname.iloc[0]
            qbreakpoint = np.max(inv_set["qend"])
            above_breakpoint = reads[(reads["qname"] == qname) & (reads["strand"] == "+") & (reads["qbegin"] >= qbreakpoint * 0.9)]
            below_breakpoint = reads[(reads["qname"] == qname) & (reads["strand"] == "+") & (reads["qend"] <= qbreakpoint * 0.9)]

            above_read_sets, above_reads = get_single_aligned(above_breakpoint, max_offset = 400,
                                                                min_seq_count = 6,
                                                                min_seq_range = 1500,
                                                                single_strand = True)
            below_read_sets, below_reads = get_single_aligned(below_breakpoint, max_offset = 400,
                                                                min_seq_count = 6,
                                                                min_seq_range = 1500,
                                                                single_strand = True)

            for i in range(len(above_read_sets)):
                for j in range(len(below_read_sets)):
                    above_set = above_read_sets[i]
                    below_set = pd.concat([below_read_sets[j], reads[(reads["qbegin"] < qbreakpoint) &  (reads["qend"] > qbreakpoint)]])
                    vbreakpoint = np.min(above_set["dbegin"]) + 200
                    below_set = below_set[below_set["dbegin"] < vbreakpoint]
                    plotted_matches = plot_breakpoint(reads.copy(), above_set.copy(), below_set.copy(), inv_set.copy())
# Out:
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 89827329.0
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 89827329.0
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 89827329.0
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 89827329.0
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 89827329.0
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 89827329.0
# 1	m54329U_190528_231241/23988940/ccs	chr2
# 1	m54329U_190528_231241/23988940/ccs	chr2

# %%
plotted_matches = plot_breakpoint(reads.copy(), above_set.copy(), below_set.copy(), inv_set.copy())
# Out:
# 89827329.0

# %%
plotted_matches.drop(["a", "b", "horizontal_error", "sum", "len"], axis = 1, inplace = True)
for col in ["dbegin", "dend", "qbegin", "qend"]:
    plotted_matches[col] = plotted_matches[col].astype(int)

plotted_matches.to_csv("HG00731.chr2.inversion.example.tsv", sep = "\t", index = False)
plotted_matches.head()
# Out:
#     dname    dbegin      dend   percid strand  \
# 264  chr2  89835039  89835231  85.0746      +
# 266  chr2  89833256  89833464  85.1674      +
# 267  chr2  89833229  89833423  85.1485      +
# 271  chr2  89832109  89832310  85.1162      +
# 272  chr2  89832105  89832316  85.2534      +
#
#                                   qname  qbegin  qend
# 264  m54329U_190528_231241/23988940/ccs    7576  7772
# 266  m54329U_190528_231241/23988940/ccs    7042  7249
# 267  m54329U_190528_231241/23988940/ccs    7701  7899
# 271  m54329U_190528_231241/23988940/ccs    8135  8346
# 272  m54329U_190528_231241/23988940/ccs    7261  7469

# %%
plotted_matches
# Out:
#     dname    dbegin      dend   percid strand  \
# 264  chr2  89835039  89835231  85.0746      +
# 266  chr2  89833256  89833464  85.1674      +
# 267  chr2  89833229  89833423  85.1485      +
# 271  chr2  89832109  89832310  85.1162      +
# 272  chr2  89832105  89832316  85.2534      +
# 273  chr2  89832070  89832306  85.0622      +
# 276  chr2  89831599  89831823  85.0877      +
# 279  chr2  89831319  89831536  85.0000      +
# 282  chr2  89830945  89831173  85.1528      +
# 284  chr2  89830945  89831140  85.0000      +
# 286  chr2  89830939  89831194  85.1145      +
# 290  chr2  89830921  89831143  85.4625      +
# 291  chr2  89830921  89831140  85.7142      +
# 294  chr2  89830865  89831107  85.0202      +
# 295  chr2  89829976  89830174  85.0746      +
# 296  chr2  89829967  89830165  85.0000      +
# 297  chr2  89829920  89830163  85.0202      +
# 307  chr2  89829322  89829582  85.1711      +
# 311  chr2  89829195  89829394  85.0241      +
# 317  chr2  89828467  89828657  85.2216      +
# 319  chr2  89827934  89828150  85.0678      +
# 320  chr2  89827887  89828094  85.1851      +
# 321  chr2  89827887  89828093  85.0000      +
# 325  chr2  89827837  89828044  85.1851      +
# 326  chr2  89827829  89828095  85.0364      +
# 330  chr2  89826355  89826558  85.0961      +
# 332  chr2  89826329  89826539  85.2534      +
# 340  chr2  89826303  89826499  85.1485      +
# 341  chr2  89826299  89826503  85.2380      +
# 342  chr2  89826292  89826535  85.2000      +
# 352  chr2  89837517  89837455  98.4126      -
# 247  chr2  89838337  89838140  85.0000      -
# 235  chr2  89838742  89838547  85.2216      -
# 228  chr2  89838797  89838599  85.0746      -
#
#                                   qname  qbegin  qend
# 264  m54329U_190528_231241/23988940/ccs    7576  7772
# 266  m54329U_190528_231241/23988940/ccs    7042  7249
# 267  m54329U_190528_231241/23988940/ccs    7701  7899
# 271  m54329U_190528_231241/23988940/ccs    8135  8346
# 272  m54329U_190528_231241/23988940/ccs    7261  7469
# 273  m54329U_190528_231241/23988940/ccs    7231  7460
# 276  m54329U_190528_231241/23988940/ccs    6636  6860
# 279  m54329U_190528_231241/23988940/ccs    4027  4243
# 282  m54329U_190528_231241/23988940/ccs    6632  6855
# 284  m54329U_190528_231241/23988940/ccs    6163  6358
# 286  m54329U_190528_231241/23988940/ccs    5639  5897
# 290  m54329U_190528_231241/23988940/ccs    5710  5932
# 291  m54329U_190528_231241/23988940/ccs    5710  5929
# 294  m54329U_190528_231241/23988940/ccs    6697  6937
# 295  m54329U_190528_231241/23988940/ccs    4745  4939
# 296  m54329U_190528_231241/23988940/ccs    2469  2665
# 297  m54329U_190528_231241/23988940/ccs    5954  6191
# 307  m54329U_190528_231241/23988940/ccs    1934  2188
# 311  m54329U_190528_231241/23988940/ccs    1501  1702
# 317  m54329U_190528_231241/23988940/ccs     777   976
# 319  m54329U_190528_231241/23988940/ccs    1121  1336
# 320  m54329U_190528_231241/23988940/ccs     605   815
# 321  m54329U_190528_231241/23988940/ccs    2807  3022
# 325  m54329U_190528_231241/23988940/ccs    1071  1282
# 326  m54329U_190528_231241/23988940/ccs     710   979
# 330  m54329U_190528_231241/23988940/ccs    2055  2255
# 332  m54329U_190528_231241/23988940/ccs     774   982
# 340  m54329U_190528_231241/23988940/ccs     138   328
# 341  m54329U_190528_231241/23988940/ccs     134   333
# 342  m54329U_190528_231241/23988940/ccs     575   815
# 352  m54329U_190528_231241/23988940/ccs    3736  3798
# 247  m54329U_190528_231241/23988940/ccs    3034  3224
# 235  m54329U_190528_231241/23988940/ccs    2646  2845
# 228  m54329U_190528_231241/23988940/ccs    2636  2829

# %% [markdown]
# #### All alignments

# %%
pid = "HG00731"
df = read_stellar_output("new_variants/" + pid + "_var.fp.gff")
len(df)
# Out:
# 701182

# %%
selected_df = pd.read_csv(pid + "_reads_of_interest.tsv", sep = "\t", header = None)
selected_df.columns = ["qname", "dname"]
selected_df.head()
# Out:
#                                  qname dname
# 0  m54329U_190528_231241/139659048/ccs  chr2
# 1  m54329U_190528_231241/165022323/ccs  chr2
# 2   m54329U_190528_231241/23988940/ccs  chr2
# 3   m54329U_190528_231241/64422157/ccs  chr2
# 4   m54329U_190528_231241/79102077/ccs  chr2

# %%
df = df[df["dname"].isin(selected_df["dname"])]
df = df[df["qname"].isin(selected_df["qname"])]
df = get_split_variants(df, min_seq_count = 3)
len(df)
# Out:
# 760

# %%
df = switch_reverse_coord(df)
df = fit_line_coord(df)
df.head()
# Out:
#        dname      dbegin        dend   percid strand   len  \
# 126239  chr2  89836743.0  89836806.0  98.4375      +  63.0
# 126602  chr2  89836744.0  89836806.0  98.4126      +  62.0
# 126987  chr2  89836748.0  89836811.0  98.4375      +  63.0
# 127434  chr2  89836753.0  89836816.0  98.4375      +  63.0
# 129647  chr2  89839676.0  89839750.0  98.6666      +  74.0
#
#                                       qname  qbegin    qend    a           b
# 126239  m54329U_190528_231241/139659048/ccs  7607.0  7670.0  1.0 -89829136.0
# 126602  m54329U_190528_231241/139659048/ccs  7613.0  7675.0  1.0 -89829131.0
# 126987  m54329U_190528_231241/139659048/ccs  7607.0  7670.0  1.0 -89829141.0
# 127434  m54329U_190528_231241/139659048/ccs  7607.0  7670.0  1.0 -89829146.0
# 129647  m54329U_190528_231241/139659048/ccs  6591.0  6665.0  1.0 -89833085.0

# %%
read_sets, split_reads = get_best_aligned(df, max_offset = 1000, 
                                              min_seq_count = 2, 
                                              min_seq_range = 1000, 
                                              single_strand = False)
len(split_reads)
# Out:
# 1	m54329U_190528_231241/139659048/ccs	chr2
# 2	m54329U_190528_231241/139659048/ccs	chr2
# 3	m54329U_190528_231241/139659048/ccs	chr2
# 4	m54329U_190528_231241/165022323/ccs	chr2
# 5	m54329U_190528_231241/23988940/ccs	chr2
# 6	m54329U_190528_231241/23988940/ccs	chr2
# 7	m54329U_190528_231241/23988940/ccs	chr2
# 8	m54329U_190528_231241/23988940/ccs	chr2
# 9	m54329U_190528_231241/23988940/ccs	chr2
# 10	m54329U_190528_231241/64422157/ccs	chr2
# 11	m54329U_190528_231241/64422157/ccs	chr2
# 12	m54329U_190528_231241/64422157/ccs	chr2
# 13	m54329U_190528_231241/64422157/ccs	chr2
# 14	m54329U_190528_231241/64422157/ccs	chr2
# 15	m54329U_190528_231241/64422157/ccs	chr2
# 16	m54329U_190528_231241/64422157/ccs	chr2
# 17	m54329U_190528_231241/64422157/ccs	chr2
# 18	m54329U_190528_231241/64422157/ccs	chr2
# 19	m54329U_190528_231241/64422157/ccs	chr2
# 20	m54329U_190528_231241/64422157/ccs	chr2
# 21	m54329U_190528_231241/64422157/ccs	chr2
# 22	m54329U_190528_231241/64422157/ccs	chr2
# 23	m54329U_190531_175004/165610554/ccs	chr2
# 24	m54329U_190531_175004/165610554/ccs	chr2
# 25	m54329U_190531_175004/43516790/ccs	chr2
# 26	m54329U_190531_175004/43516790/ccs	chr2
# 27	m54329U_190531_175004/43516790/ccs	chr2
# 28	m54329U_190531_175004/43516790/ccs	chr2
# 29	m54329U_190531_175004/75302784/ccs	chr2
# 30	m54329U_190531_175004/75302784/ccs	chr2
# 31	m54329U_190531_175004/75302784/ccs	chr2
# 32	m54329U_190531_175004/75302784/ccs	chr2
# 33	m54329U_190601_235636/137954067/ccs	chr2
# 34	m54329U_190601_235636/137954067/ccs	chr2
# 35	m54329U_190601_235636/143983600/ccs	chr2
# 36	m54329U_190601_235636/143983600/ccs	chr2
# 37	m54329U_190601_235636/143983600/ccs	chr2
# 38	m54329U_190601_235636/179503876/ccs	chr2
# 39	m54329U_190601_235636/179503876/ccs	chr2
# 40	m54329U_190601_235636/179503876/ccs	chr2
# 41	m54329U_190601_235636/179503876/ccs	chr2
# 42	m54329U_190601_235636/36833047/ccs	chr2
# 43	m54329U_190601_235636/36833047/ccs	chr2
# 44	m54329U_190601_235636/36833047/ccs	chr2
# 45	m54329U_190601_235636/36833047/ccs	chr2
# 46	m54329U_190601_235636/36833047/ccs	chr2
# 47	m54329U_190601_235636/36833047/ccs	chr2
# 48	m54329U_190601_235636/36833047/ccs	chr2
# 49	m54329U_190606_045526/128123782/ccs	chr2
# 50	m54329U_190606_045526/128123782/ccs	chr2
# 51	m54329U_190606_045526/128123782/ccs	chr2
# 52	m54329U_190606_045526/128123782/ccs	chr2
# 53	m54329U_190606_045526/128123782/ccs	chr2
# 54	m54329U_190606_045526/128123782/ccs	chr2
# 55	m54329U_190606_045526/128123782/ccs	chr2
# 56	m54329U_190606_045526/128123782/ccs	chr2
# 57	m54329U_190606_045526/128123782/ccs	chr2
# 58	m54329U_190606_045526/128123782/ccs	chr2
# 59	m54329U_190606_045526/128123782/ccs	chr2
# 60	m54329U_190606_045526/128123782/ccs	chr2
# 61	m54329U_190606_045526/128123782/ccs	chr2
# 62	m54329U_190606_045526/128123782/ccs	chr2
# 63	m54329U_190606_045526/128123782/ccs	chr2
# 64	m54329U_190606_045526/128123782/ccs	chr2
# 65	m54329U_190606_045526/128123782/ccs	chr2
# 66	m54329U_190606_045526/144572836/ccs	chr2
# 67	m54329U_190606_045526/22020333/ccs	chr2
# 68	m54329U_190606_045526/74842256/ccs	chr2
# 69	m54329U_190906_205127/115409520/ccs	chr2
# 70	m54329U_190906_205127/118032427/ccs	chr2
# 70

# %%
other_set_sets = plot_all_inversions(read_sets, df, max_offset = 1000, min_seq_count = 2, min_seq_range = 1000, read_len = 10000)
# Out:
# Match count on other strand	3
# Other strand match set count	1
# Match count on other strand	3
# Other strand match set count	2
# Match count on other strand	3
# Other strand match set count	3
# Match count on other strand	7
# Other strand match set count	4
# Match count on other strand	2
# Other strand match set count	5
# Match count on other strand	2
# Other strand match set count	6
# Match count on other strand	2
# Other strand match set count	7
# Match count on other strand	2
# Other strand match set count	8
# Match count on other strand	2
# Other strand match set count	9
# Match count on other strand	3
# Other strand match set count	10
# Match count on other strand	3
# Other strand match set count	11
# Match count on other strand	3
# Other strand match set count	12
# Match count on other strand	3
# Other strand match set count	13
# Match count on other strand	3
# Other strand match set count	14
# Match count on other strand	3
# Other strand match set count	15
# Match count on other strand	3
# Other strand match set count	16
# Match count on other strand	3
# Other strand match set count	17
# Match count on other strand	3
# Other strand match set count	18
# Match count on other strand	3
# Other strand match set count	19
# Match count on other strand	3
# Other strand match set count	20
# Match count on other strand	3
# Other strand match set count	21
# Match count on other strand	3
# Other strand match set count	22
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	1
# Other strand match set count	25
# Match count on other strand	1
# Other strand match set count	26
# Match count on other strand	1
# Other strand match set count	27
# Match count on other strand	1
# Other strand match set count	28
# Match count on other strand	1
# Other strand match set count	29
# Match count on other strand	1
# Other strand match set count	30
# Match count on other strand	1
# Other strand match set count	31
# Match count on other strand	1
# Other strand match set count	32
# Match count on other strand	12
# Other strand match set count	33
# Match count on other strand	12
# Other strand match set count	34
# Match count on other strand	1
# Other strand match set count	35
# Match count on other strand	1
# Other strand match set count	36
# Match count on other strand	1
# Other strand match set count	37
# Match count on other strand	8
# Other strand match set count	38
# Match count on other strand	8
# Other strand match set count	39
# Match count on other strand	8
# Other strand match set count	40
# Match count on other strand	4
# Other strand match set count	41
# Match count on other strand	3
# Other strand match set count	42
# Match count on other strand	3
# Other strand match set count	43
# Match count on other strand	3
# Other strand match set count	44
# Match count on other strand	3
# Other strand match set count	45
# Match count on other strand	3
# Other strand match set count	46
# Match count on other strand	3
# Other strand match set count	47
# Match count on other strand	3
# Other strand match set count	48
# Match count on other strand	4
# Other strand match set count	49
# Match count on other strand	4
# Other strand match set count	50
# Match count on other strand	4
# Other strand match set count	51
# Match count on other strand	4
# Other strand match set count	52
# Match count on other strand	4
# Other strand match set count	53
# Match count on other strand	4
# Other strand match set count	54
# Match count on other strand	4
# Other strand match set count	55
# Match count on other strand	4
# Other strand match set count	56
# Match count on other strand	4
# Other strand match set count	57
# Match count on other strand	4
# Other strand match set count	58
# Match count on other strand	4
# Other strand match set count	59
# Match count on other strand	4
# Other strand match set count	60
# Match count on other strand	4
# Other strand match set count	61
# Match count on other strand	4
# Other strand match set count	62
# Match count on other strand	0
# Match count on other strand	16
# Other strand match set count	64
# Match count on other strand	18
# Other strand match set count	65
# Match count on other strand	2
# Other strand match set count	66
# Match count on other strand	5
# Other strand match set count	67
# Match count on other strand	1
# Other strand match set count	68
# Match count on other strand	1
# Other strand match set count	69
# Match count on other strand	0

# %%
for inv_sets in other_set_sets:
    for inv_set in inv_sets:
        qname = inv_set.qname.iloc[0]
        qbreakpoint = np.max(inv_set["qend"])
        above_breakpoint = df[(df["qname"] == qname) & (df["strand"] == "+") & (df["qbegin"] >= qbreakpoint * 0.99)]
        below_breakpoint = df[(df["qname"] == qname) & (df["strand"] == "+") & (df["qend"] <= qbreakpoint * 1.01)]

        above_read_sets, above_reads = get_best_aligned(above_breakpoint, max_offset = 1000,
                                                        min_seq_count = 2,
                                                        min_seq_range = 20,
                                                        single_strand = True)
        below_read_sets, below_reads = get_best_aligned(below_breakpoint, max_offset = 1000,
                                                        min_seq_count = 2,
                                                        min_seq_range = 20,
                                                        single_strand = True)

        for i in range(len(above_read_sets)):
            for j in range(len(below_read_sets)):
                above_set = above_read_sets[i]
                below_set = pd.concat([below_read_sets[j], df[(df["qbegin"] < qbreakpoint) &  (df["qend"] > qbreakpoint)]])
                plot_breakpoint(df, above_set, below_set, inv_set)

# %% [markdown]
# ### HG00732

# %%
pid = "HG00732"
df = read_stellar_output(pid + "_var.fp.gff")
len(df)
# Out:
# 639401

# %%
selected_df = pd.read_csv(pid + "_reads_of_interest.tsv", sep = "\t", header = None)
selected_df.columns = ["qname", "dname"]
selected_df.head()
# Out:
#                                  qname dname
# 0  m54329U_190604_224858/103548289/ccs  chr2
# 1  m54329U_190604_224858/104597148/ccs  chr2
# 2  m54329U_190604_224858/107086513/ccs  chr2
# 3  m54329U_190604_224858/122619417/ccs  chr2
# 4  m54329U_190604_224858/141101371/ccs  chr2

# %%
df = df[df["dname"].isin(selected_df["dname"])]
df = df[df["qname"].isin(selected_df["qname"])]
df.head()
# Out:
#      dname    dbegin      dend   percid strand  len  \
# 6222  chr2  89828605  89828703  97.0000      +   98
# 6228  chr2  89828605  89828705  97.0297      +  100
# 6230  chr2  89828605  89828705  97.0297      +  100
# 6235  chr2  89828605  89828710  97.1962      -  105
# 6236  chr2  89828605  89828710  97.1962      +  105
#
#                                     qname  qbegin   qend
# 6222  m54329U_190604_224858/143984366/ccs    3864   3963
# 6228  m54329U_190604_224858/104597148/ccs    4581   4681
# 6230    m64076_200601_234627/16843103/ccs    9042   9142
# 6235    m64076_200601_234627/76611819/ccs   13662  13767
# 6236   m64076_200601_234627/177013911/ccs   10348  10453

# %%
df = get_split_variants(df, min_seq_count = 3)
len(df)
# Out:
# 894

# %%
df = switch_reverse_coord(df)
df = fit_line_coord(df)
df.head()
# Out:
#        dname      dbegin        dend   percid strand    len  \
# 6242    chr2  89828605.0  89828710.0  97.1698      +  105.0
# 6478    chr2  89830940.0  89831045.0  97.1698      +  105.0
# 124416  chr2  89829460.0  89829523.0  98.4375      +   63.0
# 125673  chr2  89830940.0  89831020.0  98.7654      +   80.0
# 125845  chr2  89831404.0  89831478.0  98.6666      +   74.0
#
#                                       qname  qbegin    qend    a           b
# 6242    m54329U_190604_224858/103548289/ccs  7598.0  7703.0  1.0 -89821007.0
# 6478    m54329U_190604_224858/103548289/ccs  7598.0  7703.0  1.0 -89823342.0
# 124416  m54329U_190604_224858/103548289/ccs  7598.0  7661.0  1.0 -89821862.0
# 125673  m54329U_190604_224858/103548289/ccs  7598.0  7678.0  1.0 -89823342.0
# 125845  m54329U_190604_224858/103548289/ccs  7632.0  7706.0  1.0 -89823772.0

# %%
read_sets, split_reads = get_best_aligned(df, max_offset = 1000, 
                                              min_seq_count = 2, 
                                              min_seq_range = 1000, 
                                              single_strand = False)
len(split_reads)
# Out:
# 1	m54329U_190604_224858/107086513/ccs	chr2
# 2	m54329U_190604_224858/107086513/ccs	chr2
# 3	m54329U_190604_224858/107086513/ccs	chr2
# 4	m54329U_190604_224858/107086513/ccs	chr2
# 5	m54329U_190604_224858/141101371/ccs	chr2
# 6	m54329U_190604_224858/141101371/ccs	chr2
# 7	m54329U_190604_224858/141101371/ccs	chr2
# 8	m54329U_190604_224858/141101371/ccs	chr2
# 9	m54329U_190604_224858/141101371/ccs	chr2
# 10	m54329U_190604_224858/141101371/ccs	chr2
# 11	m54329U_190604_224858/141101371/ccs	chr2
# 12	m54329U_190604_224858/143984366/ccs	chr2
# 13	m54329U_190604_224858/143984366/ccs	chr2
# 14	m54329U_190604_224858/143984366/ccs	chr2
# 15	m54329U_190604_224858/143984366/ccs	chr2
# 16	m54329U_190604_224858/143984366/ccs	chr2
# 17	m54329U_190604_224858/143984366/ccs	chr2
# 18	m54329U_190604_224858/152436925/ccs	chr2
# 19	m54329U_190604_224858/165871919/ccs	chr2
# 20	m54329U_190604_224858/165871919/ccs	chr2
# 21	m54329U_190604_224858/165871919/ccs	chr2
# 22	m54329U_190604_224858/165871919/ccs	chr2
# 23	m54329U_190604_224858/165871919/ccs	chr2
# 24	m54329U_190604_224858/39059659/ccs	chr2
# 25	m54329U_190604_224858/39059659/ccs	chr2
# 26	m54329U_190604_224858/39059659/ccs	chr2
# 27	m54329U_190604_224858/39059659/ccs	chr2
# 28	m54329U_190604_224858/39059659/ccs	chr2
# 29	m54329U_190604_224858/39059659/ccs	chr2
# 30	m54329U_190604_224858/39059659/ccs	chr2
# 31	m54329U_190604_224858/39059659/ccs	chr2
# 32	m54329U_190604_224858/39059659/ccs	chr2
# 33	m54329U_190604_224858/39059659/ccs	chr2
# 34	m54329U_190604_224858/39059659/ccs	chr2
# 35	m54329U_190604_224858/39059659/ccs	chr2
# 36	m54329U_190604_224858/39059659/ccs	chr2
# 37	m54329U_190610_071123/103612756/ccs	chr2
# 38	m54329U_190610_071123/103612756/ccs	chr2
# 39	m54329U_190610_071123/80609537/ccs	chr2
# 40	m54329U_190610_071123/80609537/ccs	chr2
# 41	m54329U_190610_071123/80609537/ccs	chr2
# 42	m54329U_190610_071123/80609537/ccs	chr2
# 43	m54329U_190610_071123/80609537/ccs	chr2
# 44	m54329U_190610_071123/80609537/ccs	chr2
# 45	m54329U_190611_132246/11993882/ccs	chr2
# 46	m54329U_190611_132246/11993882/ccs	chr2
# 47	m54329U_190611_132246/21301238/ccs	chr2
# 48	m54329U_190611_132246/21301238/ccs	chr2
# 49	m54329U_190611_132246/21301238/ccs	chr2
# 50	m54329U_190611_132246/21301238/ccs	chr2
# 51	m54329U_190611_132246/21301238/ccs	chr2
# 52	m54329U_190611_132246/21301238/ccs	chr2
# 53	m54329U_190611_132246/21301238/ccs	chr2
# 54	m54329U_190611_132246/21301238/ccs	chr2
# 55	m54329U_190611_132246/21301238/ccs	chr2
# 56	m54329U_190611_132246/21301238/ccs	chr2
# 57	m54329U_190611_132246/21301238/ccs	chr2
# 58	m54329U_190611_132246/21301238/ccs	chr2
# 59	m54329U_190611_132246/21301238/ccs	chr2
# 60	m54329U_190611_132246/21301238/ccs	chr2
# 61	m54329U_190611_132246/21301238/ccs	chr2
# 62	m54329U_190611_132246/21301238/ccs	chr2
# 63	m54329U_190611_132246/21301238/ccs	chr2
# 64	m54329U_190611_132246/21301238/ccs	chr2
# 65	m54329U_190611_132246/85002130/ccs	chr2
# 66	m54329U_190705_000551/103220931/ccs	chr2
# 67	m54329U_190705_000551/2293797/ccs	chr2
# 68	m54329U_190705_000551/2293797/ccs	chr2
# 69	m54329U_190705_000551/2293797/ccs	chr2
# 70	m54329U_190705_000551/2293797/ccs	chr2
# 71	m54329U_190705_000551/2293797/ccs	chr2
# 72	m54329U_190705_000551/2293797/ccs	chr2
# 73	m54329U_190705_000551/2293797/ccs	chr2
# 74	m54329U_190705_000551/2293797/ccs	chr2
# 75	m54329U_190705_000551/2293797/ccs	chr2
# 76	m54329U_190705_000551/2293797/ccs	chr2
# 77	m54329U_190705_000551/2293797/ccs	chr2
# 78	m54329U_190705_000551/2293797/ccs	chr2
# 79	m54329U_190705_000551/2293797/ccs	chr2
# 80	m54329U_190705_000551/5308858/ccs	chr2
# 81	m54329U_190705_000551/5308858/ccs	chr2
# 82	m54329U_190705_000551/5308858/ccs	chr2
# 83	m54329U_190705_000551/5308858/ccs	chr2
# 84	m54329U_190705_000551/5308858/ccs	chr2
# 85	m54329U_190705_000551/5308858/ccs	chr2
# 86	m54329U_190705_000551/5308858/ccs	chr2
# 87	m54329U_190705_000551/5308858/ccs	chr2
# 88	m54329U_190705_000551/5308858/ccs	chr2
# 89	m54329U_190705_000551/5308858/ccs	chr2
# 90	m54329U_190705_000551/5308858/ccs	chr2
# 91	m54329U_190705_000551/5308858/ccs	chr2
# 92	m54329U_190705_000551/5308858/ccs	chr2
# 93	m54329U_190705_000551/5308858/ccs	chr2
# 94	m54329U_190705_000551/5308858/ccs	chr2
# 95	m54329U_190705_000551/5308858/ccs	chr2
# 96	m54329U_190705_000551/5308858/ccs	chr2
# 97	m54329U_200528_200534/105974462/ccs	chr2
# 98	m54329U_200528_200534/105974462/ccs	chr2
# 99	m54329U_200528_200534/105974462/ccs	chr2
# 100	m54329U_200528_200534/166593125/ccs	chr2
# 101	m54329U_200528_200534/166593125/ccs	chr2
# 102	m54329U_200528_200534/166593125/ccs	chr2
# 103	m54329U_200528_200534/166593125/ccs	chr2
# 104	m54329U_200528_200534/166593125/ccs	chr2
# 105	m54329U_200528_200534/166593125/ccs	chr2
# 106	m54329U_200528_200534/166593125/ccs	chr2
# 107	m54329U_200528_200534/23003329/ccs	chr2
# 108	m54329U_200528_200534/23003329/ccs	chr2
# 109	m64076_200601_234627/46991548/ccs	chr4
# 110	m64076_200601_234627/46991548/ccs	chr4
# 110

# %%
other_set_sets = plot_all_inversions(read_sets, df, max_offset = 1000, min_seq_count = 2, min_seq_range = 1000, read_len = 10000)
# Out:
# Match count on other strand	1
# Other strand match set count	1
# Match count on other strand	1
# Other strand match set count	2
# Match count on other strand	1
# Other strand match set count	3
# Match count on other strand	1
# Other strand match set count	4
# Match count on other strand	17
# Other strand match set count	5
# Match count on other strand	17
# Other strand match set count	6
# Match count on other strand	17
# Other strand match set count	7
# Match count on other strand	17
# Other strand match set count	8
# Match count on other strand	17
# Other strand match set count	9
# Match count on other strand	17
# Other strand match set count	10
# Match count on other strand	17
# Other strand match set count	11
# Match count on other strand	9
# Other strand match set count	12
# Match count on other strand	9
# Other strand match set count	13
# Match count on other strand	9
# Other strand match set count	14
# Match count on other strand	9
# Other strand match set count	15
# Match count on other strand	12
# Other strand match set count	16
# Match count on other strand	6
# Other strand match set count	17
# Match count on other strand	1
# Other strand match set count	18
# Match count on other strand	2
# Other strand match set count	19
# Match count on other strand	2
# Other strand match set count	20
# Match count on other strand	2
# Other strand match set count	21
# Match count on other strand	2
# Other strand match set count	22
# Match count on other strand	2
# Other strand match set count	23
# Match count on other strand	2
# Other strand match set count	24
# Match count on other strand	2
# Other strand match set count	25
# Match count on other strand	2
# Other strand match set count	26
# Match count on other strand	2
# Other strand match set count	27
# Match count on other strand	2
# Other strand match set count	28
# Match count on other strand	2
# Other strand match set count	29
# Match count on other strand	2
# Other strand match set count	30
# Match count on other strand	2
# Other strand match set count	31
# Match count on other strand	2
# Other strand match set count	32
# Match count on other strand	2
# Other strand match set count	33
# Match count on other strand	2
# Other strand match set count	34
# Match count on other strand	2
# Other strand match set count	35
# Match count on other strand	12
# Other strand match set count	36
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	2
# Other strand match set count	39
# Match count on other strand	2
# Other strand match set count	40
# Match count on other strand	2
# Other strand match set count	41
# Match count on other strand	2
# Other strand match set count	42
# Match count on other strand	2
# Other strand match set count	43
# Match count on other strand	2
# Other strand match set count	44
# Match count on other strand	6
# Other strand match set count	45
# Match count on other strand	7
# Other strand match set count	46
# Match count on other strand	12
# Other strand match set count	47
# Match count on other strand	12
# Other strand match set count	48
# Match count on other strand	12
# Other strand match set count	49
# Match count on other strand	12
# Other strand match set count	50
# Match count on other strand	12
# Other strand match set count	51
# Match count on other strand	4
# Other strand match set count	52
# Match count on other strand	4
# Other strand match set count	53
# Match count on other strand	4
# Other strand match set count	54
# Match count on other strand	4
# Other strand match set count	55
# Match count on other strand	4
# Other strand match set count	56
# Match count on other strand	4
# Other strand match set count	57
# Match count on other strand	4
# Other strand match set count	58
# Match count on other strand	4
# Other strand match set count	59
# Match count on other strand	4
# Other strand match set count	60
# Match count on other strand	4
# Other strand match set count	61
# Match count on other strand	4
# Other strand match set count	62
# Match count on other strand	4
# Other strand match set count	63
# Match count on other strand	4
# Other strand match set count	64
# Match count on other strand	3
# Other strand match set count	65
# Match count on other strand	1
# Other strand match set count	66
# Match count on other strand	14
# Other strand match set count	67
# Match count on other strand	14
# Other strand match set count	68
# Match count on other strand	14
# Other strand match set count	69
# Match count on other strand	14
# Other strand match set count	70
# Match count on other strand	14
# Other strand match set count	71
# Match count on other strand	2
# Other strand match set count	72
# Match count on other strand	2
# Other strand match set count	73
# Match count on other strand	2
# Other strand match set count	74
# Match count on other strand	2
# Other strand match set count	75
# Match count on other strand	2
# Other strand match set count	76
# Match count on other strand	2
# Other strand match set count	77
# Match count on other strand	2
# Other strand match set count	78
# Match count on other strand	2
# Other strand match set count	79
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	1
# Other strand match set count	97
# Match count on other strand	1
# Other strand match set count	98
# Match count on other strand	1
# Other strand match set count	99
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	1
# Other strand match set count	108
# Match count on other strand	3
# Other strand match set count	109
# Match count on other strand	3
# Other strand match set count	110

# %%
for inv_sets in other_set_sets:
    for inv_set in inv_sets:
        qname = inv_set.qname.iloc[0]
        qbreakpoint = np.max(inv_set["qend"])
        above_breakpoint = df[(df["qname"] == qname) & (df["strand"] == "+") & (df["qbegin"] >= qbreakpoint * 0.99)]
        below_breakpoint = df[(df["qname"] == qname) & (df["strand"] == "+") & (df["qend"] <= qbreakpoint * 1.01)]

        above_read_sets, above_reads = get_best_aligned(above_breakpoint, max_offset = 1000,
                                                        min_seq_count = 2,
                                                        min_seq_range = 20,
                                                        single_strand = True)
        below_read_sets, below_reads = get_best_aligned(below_breakpoint, max_offset = 1000,
                                                        min_seq_count = 2,
                                                        min_seq_range = 20,
                                                        single_strand = True)

        for i in range(len(above_read_sets)):
            for j in range(len(below_read_sets)):
                above_set = above_read_sets[i]
                below_set = pd.concat([below_read_sets[j], df[(df["qbegin"] < qbreakpoint) &  (df["qend"] > qbreakpoint)]])
                plot_breakpoint(df, above_set, below_set, inv_set)

# %% [markdown]
# ### NA19238

# %%
pid = "NA19238"
df = read_stellar_output(pid + "_var.fp.gff")
len(df)
# Out:
# 37914

# %%
selected_df = pd.read_csv(pid + "_reads_of_interest.tsv", sep = "\t", header = None)
selected_df.columns = ["qname", "dname"]
selected_df.head()
# Out:
#                                 qname dname
# 0  m64039_190830_040857/150014756/ccs  chr2
# 1  m64039_190830_040857/173474075/ccs  chr5

# %%
#df = df[df["dname"].isin(selected_df["dname"])]
#df = df[df["qname"].isin(selected_df["qname"])]
df = get_split_variants(df, min_seq_count = 3)
len(df)
# Out:
# 4950

# %%
df = switch_reverse_coord(df)
df = fit_line_coord(df)
df.head()
# Out:
#        dname     dbegin       dend   percid strand   len  \
# 25900  chr21  7918143.0  7918196.0  98.1481      +  53.0
# 25933  chr21  7918143.0  7918197.0  98.1818      +  54.0
# 26374  chr21  7926161.0  7926214.0  98.1481      +  53.0
# 26760  chr21  7927256.0  7927312.0  98.2456      +  56.0
# 27035  chr21  7927258.0  7927316.0  98.3050      +  58.0
#
#                                     qname  qbegin    qend    a          b
# 25900  m64039_190830_040857/100008688/ccs  9380.0  9433.0  1.0 -7908763.0
# 25933  m64039_190830_040857/100008688/ccs  9385.0  9439.0  1.0 -7908758.0
# 26374  m64039_190830_040857/100008688/ccs  9382.0  9435.0  1.0 -7916779.0
# 26760  m64039_190830_040857/100008688/ccs  9382.0  9438.0  1.0 -7917874.0
# 27035  m64039_190830_040857/100008688/ccs  9379.0  9437.0  1.0 -7917879.0

# %%
read_sets, split_reads = get_best_aligned(df, max_offset = 2000, 
                                              min_seq_count = 1, 
                                              min_seq_range = 20, 
                                              single_strand = False)
len(split_reads)
# Out:
# 1	m64039_190830_040857/146669943/ccs	chr1
# 2	m64039_190830_040857/146669943/ccs	chr1
# 3	m64039_190830_040857/146669943/ccs	chr1
# 4	m64039_190830_040857/146669943/ccs	chr1
# 5	m64039_190830_040857/146669943/ccs	chr1
# 6	m64039_190830_040857/146669943/ccs	chr1
# 7	m64039_190830_040857/15729528/ccs	chr2
# 8	m64039_190830_040857/15729528/ccs	chr2
# 9	m64039_190830_040857/15729528/ccs	chr2
# 10	m64039_190830_040857/15729528/ccs	chr2
# 11	m64039_190830_040857/15729528/ccs	chr2
# 12	m64039_190830_040857/15729528/ccs	chr2
# 13	m64039_190830_040857/15729528/ccs	chr2
# 14	m64039_190830_040857/158728862/ccs	chr2
# 15	m64039_190830_040857/158728862/ccs	chr2
# 16	m64039_190830_040857/170657424/ccs	chr2
# 17	m64039_190830_040857/170657424/ccs	chr2
# 18	m64039_190830_040857/170657424/ccs	chr2
# 19	m64039_190830_040857/170657424/ccs	chr2
# 20	m64039_190830_040857/170657424/ccs	chr2
# 21	m64039_190830_040857/170657424/ccs	chr2
# 22	m64039_190830_040857/170657424/ccs	chr2
# 23	m64039_190830_040857/170657424/ccs	chr2
# 24	m64039_190830_040857/170657424/ccs	chr2
# 25	m64039_190830_040857/170657424/ccs	chr2
# 26	m64039_190830_040857/170657424/ccs	chr2
# 27	m64039_190830_040857/170657424/ccs	chr2
# 28	m64039_190830_040857/170657424/ccs	chr2
# 29	m64039_190830_040857/170657424/ccs	chr2
# 30	m64039_190830_040857/170657424/ccs	chr2
# 31	m64039_190830_040857/170657424/ccs	chr2
# 32	m64039_190830_040857/170657424/ccs	chr2
# 33	m64039_190830_040857/170657424/ccs	chr2
# 34	m64039_190830_040857/173474075/ccs	chr5
# 35	m64039_190830_040857/173474075/ccs	chr5
# 36	m64039_190830_040857/173474075/ccs	chr5
# 37	m64039_190830_040857/173474075/ccs	chr5
# 38	m64039_190830_040857/173474075/ccs	chr5
# 39	m64039_190830_040857/173474075/ccs	chr5
# 40	m64039_190830_040857/173474075/ccs	chr5
# 41	m64039_190830_040857/173474075/ccs	chr5
# 42	m64039_190830_040857/173474075/ccs	chr5
# 43	m64039_190830_040857/173474075/ccs	chr5
# 44	m64039_190830_040857/173474075/ccs	chr5
# 45	m64039_190830_040857/173474075/ccs	chr5
# 46	m64039_190830_040857/173474075/ccs	chr5
# 47	m64039_190830_040857/173474075/ccs	chr5
# 48	m64039_190830_040857/173474075/ccs	chr5
# 49	m64039_190830_040857/173474075/ccs	chr5
# 50	m64039_190830_040857/173474075/ccs	chr5
# 51	m64039_190830_040857/82182810/ccs	chr4
# 52	m64039_190830_040857/94045691/ccs	chr2
# 53	m64039_190830_040857/94045691/ccs	chr2
# 54	m64039_190830_040857/94045691/ccs	chr2
# 55	m64039_190830_040857/94045691/ccs	chr2
# 56	m64039_190830_040857/94045691/ccs	chr2
# 57	m64039_190830_040857/94045691/ccs	chr2
# 58	m64039_190830_040857/94045691/ccs	chr2
# 59	m64039_190830_040857/94045691/ccs	chr2
# 60	m64039_190830_040857/94045691/ccs	chr2
# 61	m64039_190830_040857/94045691/ccs	chr2
# 62	m64039_190830_040857/94045691/ccs	chr2
# 63	m64039_190830_040857/94045691/ccs	chr2
# 64	m64039_190830_040857/94045691/ccs	chr2
# 65	m64039_190830_040857/94045691/ccs	chr2
# 65

# %%
other_set_sets = plot_all_inversions(read_sets, df, max_offset = 1000, min_seq_count = 2, min_seq_range = 1000, read_len = 10000)
# Out:
# Match count on other strand	1
# Other strand match set count	1
# Match count on other strand	2
# Other strand match set count	2
# Match count on other strand	1
# Other strand match set count	3
# Match count on other strand	1
# Other strand match set count	4
# Match count on other strand	1
# Other strand match set count	5
# Match count on other strand	1
# Other strand match set count	6
# Match count on other strand	3
# Other strand match set count	7
# Match count on other strand	3
# Other strand match set count	8
# Match count on other strand	3
# Other strand match set count	9
# Match count on other strand	3
# Other strand match set count	10
# Match count on other strand	3
# Other strand match set count	11
# Match count on other strand	3
# Other strand match set count	12
# Match count on other strand	3
# Other strand match set count	13
# Match count on other strand	2
# Other strand match set count	14
# Match count on other strand	2
# Other strand match set count	15
# Match count on other strand	10
# Other strand match set count	16
# Match count on other strand	10
# Other strand match set count	17
# Match count on other strand	10
# Other strand match set count	18
# Match count on other strand	10
# Other strand match set count	19
# Match count on other strand	6
# Other strand match set count	20
# Match count on other strand	6
# Other strand match set count	21
# Match count on other strand	6
# Other strand match set count	22
# Match count on other strand	6
# Other strand match set count	23
# Match count on other strand	4
# Other strand match set count	24
# Match count on other strand	4
# Other strand match set count	25
# Match count on other strand	4
# Other strand match set count	26
# Match count on other strand	4
# Other strand match set count	27
# Match count on other strand	4
# Other strand match set count	28
# Match count on other strand	4
# Other strand match set count	29
# Match count on other strand	3
# Other strand match set count	30
# Match count on other strand	3
# Other strand match set count	31
# Match count on other strand	3
# Other strand match set count	32
# Match count on other strand	3
# Other strand match set count	33
# Match count on other strand	3
# Other strand match set count	34
# Match count on other strand	3
# Other strand match set count	35
# Match count on other strand	3
# Other strand match set count	36
# Match count on other strand	3
# Other strand match set count	37
# Match count on other strand	5
# Other strand match set count	38
# Match count on other strand	5
# Other strand match set count	39
# Match count on other strand	3
# Other strand match set count	40
# Match count on other strand	5
# Other strand match set count	41
# Match count on other strand	5
# Other strand match set count	42
# Match count on other strand	5
# Other strand match set count	43
# Match count on other strand	5
# Other strand match set count	44
# Match count on other strand	5
# Other strand match set count	45
# Match count on other strand	5
# Other strand match set count	46
# Match count on other strand	5
# Other strand match set count	47
# Match count on other strand	5
# Other strand match set count	48
# Match count on other strand	5
# Other strand match set count	49
# Match count on other strand	5
# Other strand match set count	50
# Match count on other strand	2
# Other strand match set count	51
# Match count on other strand	6
# Other strand match set count	52
# Match count on other strand	6
# Other strand match set count	53
# Match count on other strand	6
# Other strand match set count	54
# Match count on other strand	6
# Other strand match set count	55
# Match count on other strand	5
# Other strand match set count	56
# Match count on other strand	5
# Other strand match set count	57
# Match count on other strand	5
# Other strand match set count	58
# Match count on other strand	4
# Other strand match set count	59
# Match count on other strand	4
# Other strand match set count	60
# Match count on other strand	4
# Other strand match set count	61
# Match count on other strand	4
# Other strand match set count	62
# Match count on other strand	4
# Other strand match set count	63
# Match count on other strand	4
# Other strand match set count	64
# Match count on other strand	4
# Other strand match set count	65

# %%
for inv_sets in other_set_sets:
    for inv_set in inv_sets:
        qname = inv_set.qname.iloc[0]
        qbreakpoint = np.max(inv_set["qend"])
        above_breakpoint = df[(df["qname"] == qname) & (df["strand"] == "+") & (df["qbegin"] >= qbreakpoint * 0.99)]
        below_breakpoint = df[(df["qname"] == qname) & (df["strand"] == "+") & (df["qend"] <= qbreakpoint * 1.01)]

        above_read_sets, above_reads = get_single_aligned(above_breakpoint, max_offset = 2000,
                                                        min_seq_count = 2,
                                                        min_seq_range = 20,
                                                        single_strand = True)
        below_read_sets, below_reads = get_single_aligned(below_breakpoint, max_offset = 2000,
                                                        min_seq_count = 2,
                                                        min_seq_range = 20,
                                                        single_strand = True)

        for i in range(len(above_read_sets)):
            for j in range(len(below_read_sets)):
                above_set = above_read_sets[i]
                below_set = pd.concat([below_read_sets[j], df[(df["qbegin"] < qbreakpoint) &  (df["qend"] > qbreakpoint)]])
                plot_breakpoint(df, above_set, below_set, inv_set)

# %% [markdown]
# ### NA19239

# %%
pid = "NA19239"
df = read_stellar_output(pid + "_var.fp.gff")
len(df)
# Out:
# 144636

# %%
df = get_split_variants(df, min_seq_count = 1)
len(df)
# Out:
# 20573

# %%
df = switch_reverse_coord(df)
df = fit_line_coord(df)
df.head()
# Out:
#       dname     dbegin       dend   percid strand   len  \
# 25753  chr1  4303251.0  4303307.0  98.2456      +  56.0
# 27791  chr1  4303253.0  4303312.0  98.3333      +  59.0
# 27817  chr1  4303253.0  4303312.0  98.3333      +  59.0
# 22473  chr1   788758.0   788811.0  98.1481      +  53.0
# 23351  chr1   788760.0   788816.0  98.2456      +  56.0
#
#                                      qname   qbegin     qend    a          b
# 25753  m54336U_191005_142313/100207425/ccs  13283.0  13339.0  1.0 -4289968.0
# 27791  m54336U_191005_142313/100207425/ccs  13280.0  13339.0  1.0 -4289973.0
# 27817  m54336U_191005_142313/100207425/ccs  13275.0  13334.0  1.0 -4289978.0
# 22473   m54336U_191005_142313/10028137/ccs  14346.0  14399.0  1.0  -774412.0
# 23351  m54336U_191005_142313/100663676/ccs  17019.0  17075.0  1.0  -771741.0

# %%
read_sets, split_reads = get_best_aligned(df, max_offset = 1500, 
                                              min_seq_count = 3, 
                                              min_seq_range = 100, 
                                              single_strand = False)
len(split_reads)
# Out:
# 1	m54336U_191005_142313/172360688/ccs	chr2
# 2	m54336U_191005_142313/172360688/ccs	chr2
# 3	m54336U_191005_142313/172360688/ccs	chr2
# 4	m54336U_191005_142313/9439809/ccs	chr2
# 5	m54336U_191005_142313/9439809/ccs	chr2
# 6	m54336U_191005_142313/9439809/ccs	chr2
# 7	m54336U_191005_142313/9439809/ccs	chr2
# 8	m54336U_191005_142313/9439809/ccs	chr2
# 9	m54336U_191005_142313/9439809/ccs	chr2
# 10	m54336U_191005_142313/9439809/ccs	chr2
# 11	m64039_190823_190750/113574557/ccs	chr2
# 12	m64039_190823_190750/113574557/ccs	chr2
# 13	m64039_190823_190750/113574557/ccs	chr2
# 14	m64039_190823_190750/113574557/ccs	chr2
# 15	m64039_190823_190750/113574557/ccs	chr2
# 16	m64039_190823_190750/113574557/ccs	chr2
# 17	m64039_190823_190750/118227846/ccs	chr2
# 18	m64039_190823_190750/118227846/ccs	chr2
# 19	m64039_190823_190750/118227846/ccs	chr2
# 20	m64039_190823_190750/118227846/ccs	chr2
# 21	m64039_190823_190750/13698290/ccs	chr2
# 22	m64039_190823_190750/13698290/ccs	chr2
# 23	m64039_190823_190750/13698290/ccs	chr2
# 24	m64039_190823_190750/13698290/ccs	chr2
# 25	m64039_190823_190750/13698290/ccs	chr2
# 26	m64039_190823_190750/25494178/ccs	chr2
# 27	m64039_190823_190750/25494178/ccs	chr2
# 28	m64039_190823_190750/25494178/ccs	chr2
# 29	m64039_190823_190750/25494178/ccs	chr2
# 30	m64039_190823_190750/25494178/ccs	chr2
# 31	m64039_190823_190750/3539477/ccs	chr2
# 32	m64039_190823_190750/3539477/ccs	chr2
# 33	m64039_190823_190750/3539477/ccs	chr2
# 34	m64039_190823_190750/38863851/ccs	chr2
# 35	m64039_190823_190750/38863851/ccs	chr2
# 36	m64039_190823_190750/38863851/ccs	chr2
# 37	m64039_190823_190750/38863851/ccs	chr2
# 38	m64039_190823_190750/38863851/ccs	chr2
# 39	m64039_190823_190750/38863851/ccs	chr2
# 40	m64039_190823_190750/38863851/ccs	chr2
# 41	m64039_190823_190750/38863851/ccs	chr2
# 42	m64039_190823_190750/38863851/ccs	chr2
# 43	m64039_190823_190750/38863851/ccs	chr2
# 44	m64039_190823_190750/38863851/ccs	chr2
# 45	m64039_190823_190750/38863851/ccs	chr2
# 46	m64039_190823_190750/38863851/ccs	chr2
# 47	m64039_190823_190750/38863851/ccs	chr2
# 47

# %%
other_set_sets = plot_all_inversions(read_sets, df, max_offset = 1000, min_seq_count = 2, min_seq_range = 1000, read_len = 10000)
# Out:
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	1
# Other strand match set count	12
# Match count on other strand	1
# Other strand match set count	13
# Match count on other strand	1
# Other strand match set count	14
# Match count on other strand	1
# Other strand match set count	15
# Match count on other strand	1
# Other strand match set count	16
# Match count on other strand	2
# Other strand match set count	17
# Match count on other strand	2
# Other strand match set count	18
# Match count on other strand	2
# Other strand match set count	19
# Match count on other strand	2
# Other strand match set count	20
# Match count on other strand	1
# Other strand match set count	21
# Match count on other strand	1
# Other strand match set count	22
# Match count on other strand	1
# Other strand match set count	23
# Match count on other strand	1
# Other strand match set count	24
# Match count on other strand	1
# Other strand match set count	25
# Match count on other strand	8
# Other strand match set count	26
# Match count on other strand	8
# Other strand match set count	27
# Match count on other strand	8
# Other strand match set count	28
# Match count on other strand	8
# Other strand match set count	29
# Match count on other strand	8
# Other strand match set count	30
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	0
# Match count on other strand	6
# Other strand match set count	34
# Match count on other strand	6
# Other strand match set count	35
# Match count on other strand	6
# Other strand match set count	36
# Match count on other strand	6
# Other strand match set count	37
# Match count on other strand	6
# Other strand match set count	38
# Match count on other strand	6
# Other strand match set count	39
# Match count on other strand	6
# Other strand match set count	40
# Match count on other strand	6
# Other strand match set count	41
# Match count on other strand	6
# Other strand match set count	42
# Match count on other strand	6
# Other strand match set count	43
# Match count on other strand	6
# Other strand match set count	44
# Match count on other strand	6
# Other strand match set count	45
# Match count on other strand	3
# Other strand match set count	46
# Match count on other strand	3
# Other strand match set count	47

# %%
for inv_sets in other_set_sets:
    for inv_set in inv_sets:
        qname = inv_set.qname.iloc[0]
        qbreakpoint = np.max(inv_set["qend"])
        region_begin = inv_set.dbegin.iloc[0]
        above_breakpoint = df[(df["qname"] == qname) & (df["strand"] == "+") & (df["qbegin"] >= qbreakpoint * 0.99) & (df["dbegin"] > region_begin - 20000) & (df["dbegin"] < region_begin + 20000)]
        below_breakpoint = df[(df["qname"] == qname) & (df["strand"] == "+") & (df["qend"] <= qbreakpoint * 1.01) & (df["dbegin"] > region_begin - 20000) & (df["dbegin"] < region_begin + 20000)]

        above_read_sets, above_reads = get_best_aligned(above_breakpoint, max_offset = 1500,
                                                        min_seq_count = 2,
                                                        min_seq_range = 20,
                                                        single_strand = True)
        below_read_sets, below_reads = get_best_aligned(below_breakpoint, max_offset = 1500,
                                                        min_seq_count = 2,
                                                        min_seq_range = 20,
                                                        single_strand = True)

        for i in range(len(above_read_sets)):
            for j in range(len(below_read_sets)):
                above_set = above_read_sets[i]
                below_set = pd.concat([below_read_sets[j], df[(df["qbegin"] < 1000) &  (df["qend"] > 1000)]])
                plot_breakpoint(df, above_set, below_set, inv_set)
